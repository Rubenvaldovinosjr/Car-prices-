# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv('/content/drive/Shareddrives/project 3/data set/new_car_df2.csv')

df = df.drop(['vin','Unnamed: 0','sp_id','trimId'], axis = 1)

# %% [markdown]
# ##data cleaning

# %%
#cleaning up data 

df['back_legroom'] = df['back_legroom'].str.strip('in')
df['back_legroom'] = df['back_legroom'].str.strip()
df['back_legroom'] = df['back_legroom'].replace('--', 0)
df['back_legroom'] = pd.to_numeric(df['back_legroom'])
df['back_legroom'] = df['back_legroom'].fillna(int(np.mean(df['back_legroom'])))

# %%
df = df.dropna(subset = ['exterior_color'])
df['exterior_color'] = df['exterior_color'].str.lower()
# Out:
# <ipython-input-4-8a16ea1cd6a6>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['exterior_color'] = df['exterior_color'].str.lower()

# %%
df['fuel_tank_volume'] = df['fuel_tank_volume'].str.strip('gal')
df['fuel_tank_volume'] = df['fuel_tank_volume'].str.strip()
df['fuel_tank_volume'] = df['fuel_tank_volume'].replace('--', 0)
df['fuel_tank_volume'] = pd.to_numeric(df['fuel_tank_volume'])
df['fuel_tank_volume'] = df['fuel_tank_volume'].fillna(int(np.mean(df['fuel_tank_volume'])))

# %%
df['maximum_seating'] = df['maximum_seating'].str.strip('seats')
df['maximum_seating'] = df['maximum_seating'].str.strip()
df['maximum_seating'] = df['maximum_seating'].replace('--', 0)
df['maximum_seating'] = pd.to_numeric(df['maximum_seating'])
df['maximum_seating'] = df['maximum_seating'].replace(0, int(np.mean(df['maximum_seating'])))
df['maximum_seating'] = df['maximum_seating'].fillna(int(np.mean(df['maximum_seating'])))

# %%
df['height'] = df['height'].str.strip('in')
df['height'] = df['height'].str.strip()
df['height'] = df['height'].replace('--', 0)
df['height'] = pd.to_numeric(df['height'])
df['height'] = df['height'].fillna(int(np.mean(df['height'])))

# %%
df['width'] = df['width'].str.strip('in')
df['width'] = df['width'].str.strip()
df['width'] = df['width'].replace('--', 0)
df['width'] = pd.to_numeric(df['width'])
df['width'] = df['width'].fillna(int(np.mean(df['width'])))

# %%
df['wheelbase'] = df['wheelbase'].str.strip('in')
df['wheelbase'] = df['wheelbase'].str.strip()
df['wheelbase'] = df['wheelbase'].replace('--', 0)
df['wheelbase'] = pd.to_numeric(df['wheelbase'])
df['wheelbase'] = df['wheelbase'].fillna(int(np.mean(df['wheelbase'])))

# %%
df['front_legroom'] = df['front_legroom'].str.strip('in')
df['front_legroom'] = df['front_legroom'].str.strip()
df['front_legroom'] = df['front_legroom'].replace('--', 0)
df['front_legroom'] = pd.to_numeric(df['front_legroom'])
df['front_legroom'] = df['front_legroom'].fillna(int(np.mean(df['front_legroom'])))

# %%
df['length'] = df['length'].str.strip('in')
df['length'] = df['length'].str.strip()
df['length'] = df['length'].replace('--', 0)
df['length'] = pd.to_numeric(df['length'])
df['length'] = df['length'].fillna(int(np.mean(df['length'])))

# %%
df['body_type'] = df['body_type'].fillna('unknown')

# %%
df['city_fuel_economy'] = df['city_fuel_economy'].fillna(int(np.mean(df['city_fuel_economy'])))

# %%
df['engine_displacement'].unique()
# Out:
# array([2000., 1700., 2500., 3000., 2400., 3600., 3500., 6600., 4400.,
#          nan, 5300., 5400., 4600., 4700., 1400., 5500., 6200., 1500.,
#        1600., 1800., 3300., 1200., 4000., 5000., 3700., 4800., 5700.,
#        2200., 3200., 6400., 3800., 2300., 4200., 6700., 6000., 3100.,
#        5600., 2700., 2800., 1000., 4300., 5900., 1300., 5200., 6800.,
#        3400.,  700., 2900., 3900., 2100., 6100., 6300., 1900., 7300.,
#        8100.,  900., 7000., 4500., 4900., 4100., 6500., 8000., 5800.,
#        2600., 8300., 8400., 7400., 7500.])

# %%
df['engine_displacement'] = df['engine_displacement'].fillna(int(np.mean(df['engine_displacement'])))

# %%
df['engine_cylinders'] = df['engine_cylinders'].fillna('unknown')

# %%
df['engine_type'] = df['engine_type'].fillna('unknown')

# %%
df['franchise_make'] = df['franchise_make'].fillna('unknown')

# %%
df['fuel_type'] = df['fuel_type'].fillna('unknown')

# %%
df['highway_fuel_economy'] = df['highway_fuel_economy'].fillna(int(np.mean(df['highway_fuel_economy'])))

# %%
df['horsepower'] = df['horsepower'].fillna(int(np.mean(df['horsepower'])))

# %%
df['seller_rating'] = df['seller_rating'].fillna(round(df['seller_rating'].mean()))

# %%
df['mileage'] = df['mileage'].fillna(round(df['mileage'].mean()))

# %%
df['owner_count'] = df['owner_count'].fillna(round(df['owner_count'].mean()))

# %%
df['fleet'] = df['fleet'].fillna('unknown')

# %%
df['frame_damaged'] = df['frame_damaged'].fillna('unknown')

# %%
df['has_accidents'] = df['has_accidents'].fillna('unknown')

# %%
df['isCab'] = df['isCab'].fillna('unknown')

# %%
df['interior_color'] = df['interior_color'].fillna('None')

# %%
df['exterior_color'] = df['exterior_color'].fillna('None')

# %%
df['salvage'] = df['salvage'].fillna('Unknown')

# %%
df['theft_title'] = df['theft_title'].fillna('Unknown')

# %%
df['transmission_display'] = df['transmission_display'].fillna('Unknown')

# %%
df['transmission'] = df['transmission'].fillna('Unknown')

# %%
df['wheel_system'] = df['wheel_system'].fillna('Unknown')

# %%
df.isna().sum()
# Out:
# back_legroom                0
# body_type                   0
# city                        0
# city_fuel_economy           0
# daysonmarket                0
# engine_cylinders            0
# engine_displacement         0
# engine_type                 0
# exterior_color              0
# fleet                       0
# frame_damaged               0
# franchise_dealer            0
# franchise_make              0
# front_legroom               0
# fuel_tank_volume            0
# fuel_type                   0
# has_accidents               0
# height                      0
# highway_fuel_economy        0
# horsepower                  0
# interior_color              0
# isCab                       0
# is_new                      0
# latitude                    0
# length                      0
# listed_date                 0
# listing_color               0
# listing_id                  0
# longitude                   0
# make_name                   0
# maximum_seating             0
# mileage                     0
# model_name                  0
# owner_count                 0
# power                   63549
# price                       0
# salvage                     0
# savings_amount              0
# seller_rating               0
# theft_title                 0
# torque                  68419
# transmission                0
# transmission_display        0
# wheel_system                0
# wheelbase                   0
# width                       0
# dtype: int64

# %%
df['power'].unique()
# Out:
# array(['246 hp @ 5,500 RPM', '237 hp @ 6,000 RPM', '186 hp @ 6,000 RPM',
#        ..., '597 hp @ 9,000 RPM', '275 hp @ 5,400 RPM',
#        '102 hp @ 5,900 RPM'], dtype=object)

# %%
df['body_type'].unique()
# Out:
# array(['SUV / Crossover', 'Coupe', 'Sedan', 'Hatchback', 'Pickup Truck',
#        'Van', 'Minivan', 'unknown', 'Wagon', 'Convertible'], dtype=object)

# %%
df.isna().sum()
# Out:
# back_legroom                0
# body_type                   0
# city                        0
# city_fuel_economy           0
# daysonmarket                0
# engine_cylinders            0
# engine_displacement         0
# engine_type                 0
# exterior_color              0
# fleet                       0
# frame_damaged               0
# franchise_dealer            0
# franchise_make              0
# front_legroom               0
# fuel_tank_volume            0
# fuel_type                   0
# has_accidents               0
# height                      0
# highway_fuel_economy        0
# horsepower                  0
# interior_color              0
# isCab                       0
# is_new                      0
# latitude                    0
# length                      0
# listed_date                 0
# listing_color               0
# listing_id                  0
# longitude                   0
# make_name                   0
# maximum_seating             0
# mileage                     0
# model_name                  0
# owner_count                 0
# power                   63549
# price                       0
# salvage                     0
# savings_amount              0
# seller_rating               0
# theft_title                 0
# torque                  68419
# transmission                0
# transmission_display        0
# wheel_system                0
# wheelbase                   0
# width                       0
# dtype: int64

# %%
df.dtypes
# Out:
# back_legroom            float64
# body_type                object
# city                     object
# city_fuel_economy       float64
# daysonmarket              int64
# engine_cylinders         object
# engine_displacement     float64
# engine_type              object
# exterior_color           object
# fleet                    object
# frame_damaged            object
# franchise_dealer           bool
# franchise_make           object
# front_legroom           float64
# fuel_tank_volume        float64
# fuel_type                object
# has_accidents            object
# height                  float64
# highway_fuel_economy    float64
# horsepower              float64
# interior_color           object
# isCab                    object
# is_new                     bool
# latitude                float64
# length                  float64
# listed_date              object
# listing_color            object
# listing_id                int64
# longitude               float64
# make_name                object
# maximum_seating         float64
# mileage                 float64
# model_name               object
# owner_count             float64
# power                    object
# price                   float64
# salvage                  object
# savings_amount            int64
# seller_rating           float64
# theft_title              object
# torque                   object
# transmission             object
# transmission_display     object
# wheel_system             object
# wheelbase               float64
# width                   float64
# dtype: object

# %%
df.isna().sum()/len(df)
# Out:
# back_legroom            0.000000
# body_type               0.000000
# city                    0.000000
# city_fuel_economy       0.000000
# daysonmarket            0.000000
# engine_cylinders        0.000000
# engine_displacement     0.000000
# engine_type             0.000000
# exterior_color          0.000000
# fleet                   0.000000
# frame_damaged           0.000000
# franchise_dealer        0.000000
# franchise_make          0.000000
# front_legroom           0.000000
# fuel_tank_volume        0.000000
# fuel_type               0.000000
# has_accidents           0.000000
# height                  0.000000
# highway_fuel_economy    0.000000
# horsepower              0.000000
# interior_color          0.000000
# isCab                   0.000000
# is_new                  0.000000
# latitude                0.000000
# length                  0.000000
# listed_date             0.000000
# listing_color           0.000000
# listing_id              0.000000
# longitude               0.000000
# make_name               0.000000
# maximum_seating         0.000000
# mileage                 0.000000
# model_name              0.000000
# owner_count             0.000000
# power                   0.158873
# price                   0.000000
# salvage                 0.000000
# savings_amount          0.000000
# seller_rating           0.000000
# theft_title             0.000000
# torque                  0.171048
# transmission            0.000000
# transmission_display    0.000000
# wheel_system            0.000000
# wheelbase               0.000000
# width                   0.000000
# dtype: float64

# %% [markdown]
# ##data exploration

# %%
df['body_type'].unique()
# Out:
# array(['SUV / Crossover', 'Coupe', 'Sedan', 'Hatchback', 'Pickup Truck',
#        'Van', 'Minivan', 'unknown', 'Wagon', 'Convertible'], dtype=object)

# %%
df.head()
# Out:
#    back_legroom        body_type      city  city_fuel_economy  daysonmarket  \
# 0          38.1  SUV / Crossover  San Juan               22.0           207
# 1           0.0            Coupe  Guaynabo               22.0          1252
# 2          38.1  SUV / Crossover  San Juan               22.0           230
# 3          35.1            Sedan   Bayamon               22.0           447
# 4          35.0  SUV / Crossover   Bayamon               22.0           529
#
#   engine_cylinders  engine_displacement engine_type  \
# 0               I4               2000.0          I4
# 1               I4               1700.0          I4
# 2               I4               2000.0          I4
# 3               I4               2500.0          I4
# 4               I4               2000.0          I4
#
#                exterior_color    fleet  ...  salvage  savings_amount  \
# 0                narvik black  unknown  ...  Unknown               0
# 1                         red    False  ...    False               0
# 2             santorini black  unknown  ...  Unknown               0
# 3  snowflake white pearl mica  unknown  ...  Unknown               0
# 4       snowflake white pearl  unknown  ...  Unknown               0
#
#   seller_rating  theft_title                 torque transmission  \
# 0           3.0      Unknown  269 lb-ft @ 1,400 RPM            A
# 1           4.0        False  258 lb-ft @ 4,250 RPM            A
# 2           3.0      Unknown  269 lb-ft @ 1,400 RPM            A
# 3           2.8      Unknown  186 lb-ft @ 4,000 RPM            A
# 4           2.8      Unknown  146 lb-ft @ 2,800 RPM            A
#
#           transmission_display  wheel_system  wheelbase  width
# 0  9-Speed Automatic Overdrive           AWD      107.9   85.6
# 1            6-Speed Automatic           RWD       93.7   73.5
# 2  9-Speed Automatic Overdrive           AWD      107.9   85.6
# 3  6-Speed Automatic Overdrive           FWD      107.3   70.7
# 4  6-Speed Automatic Overdrive           FWD      101.2   69.6
#
# [5 rows x 46 columns]

# %%
df.columns
# Out:
# Index(['back_legroom', 'body_type', 'city', 'city_fuel_economy',
#        'daysonmarket', 'engine_cylinders', 'engine_displacement',
#        'engine_type', 'exterior_color', 'fleet', 'frame_damaged',
#        'franchise_dealer', 'franchise_make', 'front_legroom',
#        'fuel_tank_volume', 'fuel_type', 'has_accidents', 'height',
#        'highway_fuel_economy', 'horsepower', 'interior_color', 'isCab',
#        'is_new', 'latitude', 'length', 'listed_date', 'listing_color',
#        'listing_id', 'longitude', 'make_name', 'maximum_seating', 'mileage',
#        'model_name', 'owner_count', 'power', 'price', 'salvage',
#        'savings_amount', 'seller_rating', 'theft_title', 'torque',
#        'transmission', 'transmission_display', 'wheel_system', 'wheelbase',
#        'width'],
#       dtype='object')

# %%
from sklearn.model_selection import train_test_split

X = df[['daysonmarket','seller_rating','owner_count']]
y = df['price']

X_train,X_test,y_train,y_test = train_test_split(X,y,train_size = 0.7)

# %%
from sklearn.linear_model import LinearRegression

lr = LinearRegression()

lr.fit(X_train,y_train)

X_test['predictions'] = lr.predict(X_test)

# %%
lr.coef_
# Out:
# array([  12.1815687 , 2634.99251264, -219.85098528])

# %%
plt.figure(figsize = (12,8))
plt.scatter(y_test,X_test['predictions'])
plt.xlim(0, 750000)

plt.xlabel('Actual Price', size = 15)
plt.ylabel('Predicted Price', size = 15)
plt.title('Actual Price vs Predicted Price', size = 20)
# Out:
# Text(0.5, 1.0, 'Actual Price vs Predicted Price')

# %%
X2 = df[['daysonmarket','seller_rating','owner_count','front_legroom','back_legroom','width','height','length','mileage', 'horsepower', 'highway_fuel_economy', 'fuel_tank_volume']]
y2 = df['price']

X_train2,X_test2,y_train2,y_test2 = train_test_split(X2,y2,train_size = 0.7)

lr.fit(X_train2,y_train2)

X_test2['predictions'] = lr.predict(X_test2)

# %%
lr.coef_
# Out:
# array([ 6.14338467e+00,  1.74094320e+03,  1.49977470e+03, -9.15661303e+02,
#         4.24847185e+01, -3.28578491e+00,  7.49294919e+01, -8.42744426e+01,
#        -1.92621322e-01,  1.29605960e+02,  1.31813160e+02,  2.03242668e+02])

# %%
plt.figure(figsize = (12,8))
plt.scatter(y_test2,X_test2['predictions'])
plt.xlim(0, 500000)
plt.ylim(0,200000)

plt.xlabel('Actual Price', size = 15)
plt.ylabel('Predicted Price', size = 15)
plt.title('Actual Price vs Predicted Price', size = 20)
# Out:
# Text(0.5, 1.0, 'Actual Price vs Predicted Price')

# %%
df.corr()
# Out:
#                       back_legroom  city_fuel_economy  daysonmarket  \
# back_legroom              1.000000          -0.024330     -0.051248
# city_fuel_economy        -0.024330           1.000000      0.008689
# daysonmarket             -0.051248           0.008689      1.000000
# engine_displacement       0.017939          -0.403924     -0.043802
# franchise_dealer          0.089891           0.054141      0.005132
# front_legroom             0.346531           0.013689     -0.027771
# fuel_tank_volume          0.033929          -0.401701     -0.021521
# height                    0.068145          -0.334615     -0.007441
# highway_fuel_economy     -0.033269           0.940318      0.001439
# horsepower                0.035264          -0.442705     -0.019724
# is_new                    0.060172           0.091459      0.174536
# latitude                  0.005744          -0.035565      0.017992
# length                    0.113379          -0.306314     -0.036523
# listing_id                0.051094          -0.005402     -0.997407
# longitude                 0.002992          -0.077624      0.010760
# maximum_seating           0.430720          -0.224285     -0.026775
# mileage                  -0.053448          -0.131596     -0.081267
# owner_count              -0.054681          -0.038706      0.124200
# price                    -0.009589          -0.154301      0.067524
# savings_amount           -0.072661          -0.088527     -0.080363
# seller_rating            -0.020510          -0.033111     -0.004309
# wheelbase                 0.099829          -0.294230     -0.027197
# width                     0.040092          -0.309342      0.020137
#
#                       engine_displacement  franchise_dealer  front_legroom  \
# back_legroom                     0.017939          0.089891       0.346531
# city_fuel_economy               -0.403924          0.054141       0.013689
# daysonmarket                    -0.043802          0.005132      -0.027771
# engine_displacement              1.000000         -0.058333       0.066696
# franchise_dealer                -0.058333          1.000000       0.023025
# front_legroom                    0.066696          0.023025       1.000000
# fuel_tank_volume                 0.816595         -0.029320       0.051096
# height                           0.587992          0.079158       0.039595
# highway_fuel_economy            -0.464608          0.037984       0.037652
# horsepower                       0.830402          0.025112      -0.014016
# is_new                          -0.064317          0.472105       0.000449
# latitude                        -0.004296          0.006329       0.000651
# length                           0.772743          0.028234       0.141634
# listing_id                       0.040369          0.001100       0.027985
# longitude                       -0.007421          0.016830       0.006453
# maximum_seating                  0.321908          0.023064       0.060113
# mileage                          0.140859         -0.515943      -0.004714
# owner_count                      0.053949         -0.058113      -0.034826
# price                            0.354311          0.282827      -0.169929
# savings_amount                   0.132422         -0.216703      -0.061148
# seller_rating                    0.025989         -0.030356      -0.028348
# wheelbase                        0.755337          0.040398       0.120304
# width                            0.465118          0.072622       0.053309
#
#                       fuel_tank_volume    height  highway_fuel_economy  \
# back_legroom                  0.033929  0.068145             -0.033269
# city_fuel_economy            -0.401701 -0.334615              0.940318
# daysonmarket                 -0.021521 -0.007441              0.001439
# engine_displacement           0.816595  0.587992             -0.464608
# franchise_dealer             -0.029320  0.079158              0.037984
# front_legroom                 0.051096  0.039595              0.037652
# fuel_tank_volume              1.000000  0.717596             -0.472360
# height                        0.717596  1.000000             -0.484679
# highway_fuel_economy         -0.472360 -0.484679              1.000000
# horsepower                    0.760002  0.519891             -0.512239
# is_new                       -0.029507  0.111529              0.052678
# latitude                      0.007429  0.041247             -0.056615
# length                        0.845630  0.687186             -0.356694
# listing_id                    0.019540  0.007759              0.001358
# longitude                     0.007221  0.033861             -0.074530
# maximum_seating               0.337233  0.417861             -0.270499
# mileage                       0.108699 -0.019182             -0.119517
# owner_count                   0.024146 -0.004047             -0.055493
# price                         0.372902  0.294860             -0.220049
# savings_amount                0.115170 -0.000528             -0.084160
# seller_rating                 0.039904  0.027166             -0.042592
# wheelbase                     0.842332  0.719447             -0.361475
# width                         0.633415  0.594236             -0.371075
#
#                       horsepower  ...  listing_id  longitude  maximum_seating  \
# back_legroom            0.035264  ...    0.051094   0.002992         0.430720
# city_fuel_economy      -0.442705  ...   -0.005402  -0.077624        -0.224285
# daysonmarket           -0.019724  ...   -0.997407   0.010760        -0.026775
# engine_displacement     0.830402  ...    0.040369  -0.007421         0.321908
# franchise_dealer        0.025112  ...    0.001100   0.016830         0.023064
# front_legroom          -0.014016  ...    0.027985   0.006453         0.060113
# fuel_tank_volume        0.760002  ...    0.019540   0.007221         0.337233
# height                  0.519891  ...    0.007759   0.033861         0.417861
# highway_fuel_economy   -0.512239  ...    0.001358  -0.074530        -0.270499
# horsepower              1.000000  ...    0.017959  -0.010268         0.304156
# is_new                  0.007821  ...   -0.161207  -0.009090        -0.012108
# latitude               -0.013163  ...   -0.020974   0.168571         0.000980
# length                  0.724271  ...    0.034917  -0.012142         0.346518
# listing_id              0.017959  ...    1.000000  -0.017207         0.025934
# longitude              -0.010268  ...   -0.017207   1.000000        -0.000484
# maximum_seating         0.304156  ...    0.025934  -0.000484         1.000000
# mileage                -0.014958  ...    0.072603   0.009382         0.039821
# owner_count             0.007390  ...   -0.119791  -0.011426        -0.047093
# price                   0.567680  ...   -0.063079  -0.026351         0.126902
# savings_amount          0.151669  ...    0.074323  -0.008846         0.008655
# seller_rating           0.059798  ...    0.003553   0.000864         0.009504
# wheelbase               0.703494  ...    0.026235  -0.012542         0.276895
# width                   0.624062  ...   -0.018928   0.007388         0.284475
#
#                        mileage  owner_count     price  savings_amount  \
# back_legroom         -0.053448    -0.054681 -0.009589       -0.072661
# city_fuel_economy    -0.131596    -0.038706 -0.154301       -0.088527
# daysonmarket         -0.081267     0.124200  0.067524       -0.080363
# engine_displacement   0.140859     0.053949  0.354311        0.132422
# franchise_dealer     -0.515943    -0.058113  0.282827       -0.216703
# front_legroom        -0.004714    -0.034826 -0.169929       -0.061148
# fuel_tank_volume      0.108699     0.024146  0.372902        0.115170
# height               -0.019182    -0.004047  0.294860       -0.000528
# highway_fuel_economy -0.119517    -0.055493 -0.220049       -0.084160
# horsepower           -0.014958     0.007390  0.567680        0.151669
# is_new               -0.627173     0.331561  0.381612       -0.501954
# latitude              0.053042    -0.011888 -0.025016       -0.008025
# length                0.021777     0.003071  0.356793        0.061335
# listing_id            0.072603    -0.119791 -0.063079        0.074323
# longitude             0.009382    -0.011426 -0.026351       -0.008846
# maximum_seating       0.039821    -0.047093  0.126902        0.008655
# mileage               1.000000     0.151140 -0.443080        0.246693
# owner_count           0.151140     1.000000 -0.001134       -0.213488
# price                -0.443080    -0.001134  1.000000       -0.008213
# savings_amount        0.246693    -0.213488 -0.008213        1.000000
# seller_rating         0.030827    -0.005296  0.070604        0.012608
# wheelbase            -0.000677     0.009110  0.358401        0.054139
# width                -0.068885    -0.017692  0.368656        0.052292
#
#                       seller_rating  wheelbase     width
# back_legroom              -0.020510   0.099829  0.040092
# city_fuel_economy         -0.033111  -0.294230 -0.309342
# daysonmarket              -0.004309  -0.027197  0.020137
# engine_displacement        0.025989   0.755337  0.465118
# franchise_dealer          -0.030356   0.040398  0.072622
# front_legroom             -0.028348   0.120304  0.053309
# fuel_tank_volume           0.039904   0.842332  0.633415
# height                     0.027166   0.719447  0.594236
# highway_fuel_economy      -0.042592  -0.361475 -0.371075
# horsepower                 0.059798   0.703494  0.624062
# is_new                    -0.033201   0.067862  0.084337
# latitude                   0.089489  -0.014215  0.009633
# length                     0.024124   0.965909  0.642427
# listing_id                 0.003553   0.026235 -0.018928
# longitude                  0.000864  -0.012542  0.007388
# maximum_seating            0.009504   0.276895  0.284475
# mileage                    0.030827  -0.000677 -0.068885
# owner_count               -0.005296   0.009110 -0.017692
# price                      0.070604   0.358401  0.368656
# savings_amount             0.012608   0.054139  0.052292
# seller_rating              1.000000   0.022915  0.058968
# wheelbase                  0.022915   1.000000  0.648697
# width                      0.058968   0.648697  1.000000
#
# [23 rows x 23 columns]

# %%
X3 = df[['engine_displacement', 'front_legroom','fuel_tank_volume','height','highway_fuel_economy','horsepower','mileage','owner_count']]
y3 = df['price']

X_train3,X_test3,y_train3,y_test3 = train_test_split(X3,y3,train_size = 0.7)

lr.fit(X_train3,y_train3)

X_test3['predictions'] = lr.predict(X_test3)

# %%
lr.coef_
# Out:
# array([-2.84088948e+00, -8.41950456e+02,  2.59270909e+02,  6.55752823e+01,
#         1.04015386e+02,  1.47686259e+02, -1.83333812e-01,  1.76228618e+03])

# %%
plt.figure(figsize=(12,8))
plt.scatter(y_test3,X_test3['predictions'])
plt.xlim(0,500000)
plt.ylim(0,200000)

plt.xlabel('Actual Price', size = 15)
plt.ylabel('Predicted Price', size = 15)
plt.title('Actual Price vs Predicted Price', size = 20)
# Out:
# Text(0.5, 1.0, 'Actual Price vs Predicted Price')

# %% [markdown]
# ##Decision Tree Regressor (SUV)

# %%
df_SUV = df[df['body_type'] == 'SUV / Crossover']

# %%
X4 = df_SUV[['mileage','owner_count','front_legroom','back_legroom','width','height','length']]
y4 = df_SUV['price']

X_train4,X_test4,y_train4,y_test4 = train_test_split(X4,y4,train_size = 0.7)

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import GridSearchCV

dtr_suv = DecisionTreeRegressor()

dtr_params = {'max_depth': [2, 5, 10, 25, 50],
             'min_samples_split': [5, 10, 25, 50, 100],
             'min_samples_leaf': [5, 10, 25, 50, 100]}

grid_search_dtr = GridSearchCV(dtr_suv, dtr_params)

grid_search_dtr.fit(X_train4,y_train4)

grid_search_dtr.best_params_
# Out:
# {'max_depth': 25, 'min_samples_leaf': 5, 'min_samples_split': 50}

# %%
suv_preds = grid_search_dtr.predict(X_test4)

# %%
plt.figure(figsize=(12,8))
plt.scatter(y_test4,suv_preds)
plt.xlim(0,200000)
plt.ylim(0,200000)

plt.xlabel('SUV Actual Price', size = 15)
plt.ylabel('SUV Predicted Price', size = 15)
plt.title('Actual Price vs Predicted Price for SUV', size = 20)
# Out:
# Text(0.5, 1.0, 'Actual Price vs Predicted Price for SUV')

# %%
grid_search_dtr.score(X_test4,y_test4)
# Out:
# 0.873490814902708

# %% [markdown]
# ##Decision Tree Regressor (Pick Up)

# %%
df['body_type'].unique()
# Out:
# array(['SUV / Crossover', 'Coupe', 'Sedan', 'Hatchback', 'Pickup Truck',
#        'Van', 'Minivan', 'unknown', 'Wagon', 'Convertible'], dtype=object)

# %%
df_pickup = df[df['body_type'] == 'Pickup Truck']

# %%
X5 = df_pickup[['mileage','owner_count','front_legroom','back_legroom','width','height','length']]
y5 = df_pickup['price']

X_train5,X_test5,y_train5,y_test5 = train_test_split(X5,y5,train_size = 0.7)

# %%
dtr_pickup = DecisionTreeRegressor()

dtr_params = {'max_depth': [2, 5, 10, 25, 50],
             'min_samples_split': [5, 10, 25, 50, 100],
             'min_samples_leaf': [5, 10, 25, 50, 100]}

grid_search_dtr = GridSearchCV(dtr_pickup, dtr_params)

grid_search_dtr.fit(X_train5,y_train5)

grid_search_dtr.best_params_
# Out:
# {'max_depth': 25, 'min_samples_leaf': 5, 'min_samples_split': 100}

# %%
pickup_preds = grid_search_dtr.predict(X_test5)

# %%
plt.figure(figsize=(12,8))
plt.scatter(y_test5,pickup_preds)
plt.xlim(0,125000)
plt.ylim(0,125000)

plt.xlabel('Pickup Actual Price', size = 15)
plt.ylabel('Pickup Predicted Price', size = 15)
plt.title('Actual Price vs Predicted Price for Pickup Trucks', size = 20)
# Out:
# Text(0.5, 1.0, 'Actual Price vs Predicted Price for Pickup Trucks')

# %%
grid_search_dtr.score(X_test5,y_test5)
# Out:
# 0.7525384617639032

# %% [markdown]
# ##Decision Tree Regressor (Everything Else)

# %%
df2= df[df['body_type'] != 'Pickup Truck']

df_other = df2[df2['body_type'] != 'SUV / Crossover']

# %%
df_other['body_type'].unique()
# Out:
# array(['Coupe', 'Sedan', 'Hatchback', 'Van', 'Minivan', 'unknown',
#        'Wagon', 'Convertible'], dtype=object)

# %%
X6 = df_other[['mileage','owner_count','front_legroom','back_legroom','width','height','length']]
y6 = df_other['price']

X_train6,X_test6,y_train6,y_test6 = train_test_split(X6,y6,train_size = 0.7)

# %%
dtr_other = DecisionTreeRegressor()

dtr_params = {'max_depth': [2, 5, 10, 25, 50],
             'min_samples_split': [5, 10, 25, 50, 100],
             'min_samples_leaf': [5, 10, 25, 50, 100]}

grid_search_dtr = GridSearchCV(dtr_other, dtr_params)

grid_search_dtr.fit(X_train6,y_train6)

grid_search_dtr.best_params_
# Out:
# {'max_depth': 50, 'min_samples_leaf': 5, 'min_samples_split': 50}

# %%
other_preds = grid_search_dtr.predict(X_test6)

# %%
plt.figure(figsize=(12,8))
plt.scatter(y_test6,other_preds)
plt.xlim(0,250000)
plt.ylim(0,250000)

plt.xlabel('Other Actual Price', size = 15)
plt.ylabel('Other Predicted Price', size = 15)
plt.title('Actual Price vs Predicted Price for All Other Cars', size = 20)
# Out:
# Text(0.5, 1.0, 'Actual Price vs Predicted Price for All Other Cars')

# %%
grid_search_dtr.score(X_test6,y_test6)
# Out:
# 0.5608829947253724

# %% [markdown]
# ##KNN Regressor SUVs

# %%
from sklearn.neighbors import KNeighborsRegressor

knn_params = {'n_neighbors': [1, 5, 10, 25, 50, 100, 150, 200],
              'metric':['euclidean']}

knn_R = KNeighborsRegressor()

grid_search_knn = GridSearchCV(knn_R, knn_params)

grid_search_knn.fit(X_train4, y_train4)

knn_r_preds=grid_search_knn.predict(X_test4)

knn_acc = grid_search_knn.score(X_test4, y_test4)

knn_acc
# Out:
# 0.7285611418190034

# %%
grid_search_knn.best_params_
# Out:
# {'metric': 'euclidean', 'n_neighbors': 10}

# %%
plt.figure(figsize=(12,8))
plt.scatter(y_test4,knn_r_preds)
plt.xlim(0,150000)
plt.ylim(0,150000)

plt.xlabel('SUV Actual Price', size = 15)
plt.ylabel('SUV Predicted Price', size = 15)
plt.title('Actual Price vs Predicted Price for SUVs', size = 20)
# Out:
# Text(0.5, 1.0, 'Actual Price vs Predicted Price for SUVs')

# %% [markdown]
# ##KNN Pickup

# %%
from sklearn.neighbors import KNeighborsRegressor

knn_params = {'n_neighbors': [5, 10, 25, 50, 100, 150, 200],
              'metric':['euclidean']}

knn_R = KNeighborsRegressor()

grid_search_knn = GridSearchCV(knn_R, knn_params)

grid_search_knn.fit(X_train5, y_train5)

knn_r_preds=grid_search_knn.predict(X_test5)

knn_acc = grid_search_knn.score(X_test5, y_test5)

knn_acc
# Out:
# 0.632785182049458

# %%
grid_search_knn.best_params_
# Out:
# {'metric': 'euclidean', 'n_neighbors': 25}

# %%
plt.figure(figsize=(12,8))
plt.scatter(y_test5,knn_r_preds)
plt.xlim(0,100000)
plt.ylim(0,100000)

plt.xlabel('Pickups Actual Price', size = 15)
plt.ylabel('Pickups Predicted Price', size = 15)
plt.title('Actual Price vs Predicted Price for Pickups', size = 20)
# Out:
# Text(0.5, 1.0, 'Actual Price vs Predicted Price for Pickups')

# %%
knn_acc
# Out:
# 0.632785182049458

# %% [markdown]
# ##KNN All other cars

# %%
knn_params = {'n_neighbors': [5, 10, 25, 50, 100, 150, 200],
              'metric':['euclidean']}

knn_R = KNeighborsRegressor()

grid_search_knn = GridSearchCV(knn_R, knn_params)

grid_search_knn.fit(X_train6, y_train6)

knn_r_preds=grid_search_knn.predict(X_test6)

knn_acc = grid_search_knn.score(X_test6, y_test6)

grid_search_knn.best_params_
# Out:
# {'metric': 'euclidean', 'n_neighbors': 10}

# %%
plt.figure(figsize=(12,8))
plt.scatter(y_test6,knn_r_preds)
plt.xlim(0,200000)
plt.ylim(0,200000)

plt.xlabel('Other Actual Price', size = 15)
plt.ylabel('Other Predicted Price', size = 15)
plt.title('Actual Price vs Predicted Price for All Other Cars', size = 20)
# Out:
# Text(0.5, 1.0, 'Actual Price vs Predicted Price for All Other Cars')

# %%
knn_acc
# Out:
# 0.38280354840549236

# %% [markdown]
# ##KNN SUVs Savala Code

# %%
from sklearn.neighbors import KNeighborsRegressor

# %%
continuous_cols=['mileage','owner_count','front_legroom','back_legroom','width','height']
categorical_cols=['object','fleet','model_name','body_type']

# %%
def make_distance_matrix(X, continuous_cols, categorical_cols):
  # Continuous columns
  from sklearn.metrics import DistanceMetric
  euc_dist = DistanceMetric.get_metric('euclidean')
  
  continuous_dist = euc_dist.pairwise(X[continuous_cols])

  # Categorical columns
  hamming_dist = DistanceMetric.get_metric('hamming')
  hamming_dist.pairwise(X[categorical_cols])

  # Total distance
  X_dist = continuous_dist + hamming_dist
  
  return(X_dist)

# %%
# # Fit your nn model
# # Set metric to "precomputed" to tell it to use a distance matrix
# knn = KNeighborsRegressor(n_neighbors=5, metric="precomputed")
# # Make sure to use the distance matrix
# X_train_dist = make_distance_matrix(df_SUV,['mileage','owner_count','front_legroom','back_legroom','width','height'],categorical_cols=['object','fleet','model_name','body_type'])

# knn.fit(X_train_dist, y_train4)

# # Make predictions
# X_test_dist = make_distance_matrix(X_test)
# knn.predict(X_test_dist)
